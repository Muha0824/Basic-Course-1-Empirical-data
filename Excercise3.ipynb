# %%
import pandas as pd
import matplotlib

# %% [markdown]
# # Excercise 3.1 : Data in Pandas

# %%
df = pd.read_csv('birch_tree-ex.csv')
s_flooded= pd.Series(df['Control'])
s_flooded
# Out:
# 0    1.70
# 1    2.04
# 2    1.49
# 3    1.91
# Name: Control, dtype: float64

# %%
df
# Out:
#    Flooded  Control
# 0     1.45     1.70
# 1     1.19     2.04
# 2     1.05     1.49
# 3     1.07     1.91

# %% [markdown]
# # Excercise 3.2 : Common Code error

# %%
s = pd . Series ([1 ,45 1 ,19 1 ,05 1 ,07])
s = Series ([1.45 , 1.19 , 1.05 , 1.07])
flooded data = pd . Series ([1.45 , 1.19 , 1.05 , 1.07])
# Out:
#   Cell In[5], line 1
#     s = pd . Series ([1 ,45 1 ,19 1 ,05 1 ,07])
#                                      ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers

# %% [markdown]
# Their is several mistakes, like flooded data is seperated, and thus giving it error, to make it work it has to be called flooded_data.
#
# Also pd have spaces with series, and 05, I suppose thier should be a dot between them if its a continues value.
#
# We also have confliction variables that are being turned to a series. So, a new name like s_new will be fine to distiguish the difference. And also series has to be written using pd.series We also missing lots of commans

# %%
s = pd.Series([1 ,45 , 1 ,19, 1 ,0.5 , 1 ,0.7])
s_new = pd.Series([1.45 , 1.19 , 1.05 , 1.07])
flooded_data = pd.Series(s_new)

# %% [markdown]
# # Excercise 3.3 : Create a DataFrame

# %%
df = pd.DataFrame({
    'reds':[2],
    'green':[4],
    'blue':[6]

})

df
# Out:
#    reds  green  blue
# 0     2      4     6

# %%
df.plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# # Excercise 3.4: Creating a CSV file

# %%
df = pd.read_csv('atp.csv')
df
# Out:
#    Flooded  Control
# 0     1.45     1.70
# 1     1.19     2.04
# 2     1.05     1.49
# 3     1.07     1.91

# %%
f = 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/4.5_day.csv'
df = pd.read_csv(f)
df
# Out:
#                         time  latitude  longitude   depth  mag magType  nst  \
# 0   2025-09-08T11:39:52.328Z    7.7599   136.7296  10.000  4.7      mb   46
# 1   2025-09-08T11:32:31.947Z   52.5236   160.8244  10.000  5.2      mb  116
# 2   2025-09-08T08:26:11.848Z   52.4805   160.6694  10.000  5.1      mb   68
# 3   2025-09-08T05:50:45.381Z   23.7403   122.5330  10.000  4.8      mb   67
# 4   2025-09-08T04:23:05.156Z   -1.0102   134.2058  36.169  4.5      mb   34
# 5   2025-09-08T03:45:47.753Z   32.4152   141.7504  10.000  4.6      mb   47
# 6   2025-09-08T03:09:58.705Z  -58.3414   -15.8639  10.000  5.1      mb   69
# 7   2025-09-08T01:27:24.814Z  -50.7730   162.2429  14.324  5.2     mww   56
# 8   2025-09-07T21:56:10.973Z   41.9534    81.9661  34.073  4.5      mb   57
# 9   2025-09-07T21:25:00.850Z   50.9644   156.9651  88.136  5.0      mb   96
# 10  2025-09-07T19:08:42.157Z   50.0898   155.8323  83.441  4.8      mb   65
# ...

# %% [markdown]
# # Exercise 3.5: Collect popcorn data

# %% [markdown]
# Well it would be cool to see if like does the length of of the popcorn determine its color. or see the corrleation. This would be a catogorical (ordinal) because we sort it through like colors and numerical(continuous) value given its length
#
# speed of the kernal's pop and its pop speed.

# %%
# As this data is avaliable from the compendium, I am just going to use it 

df = pd.DataFrame({
    'Popped':[True,True, False,True], 
    'Long length (mm)':[11,13,5,15], 
    'Short length (mm)' : [7,6,4,14], 
    'color':["White","white","brown","yellow"]
})

df
# Out:
#    Popped  Long length (mm)  Short length (mm)   color
# 0    True                11                  7   White
# 1    True                13                  6   white
# 2   False                 5                  4   brown
# 3    True                15                 14  yellow

# %% [markdown]
# # Excercise 3.6:Sneak peek of popcorn data

# %%
import pandas as pd 
df = pd.read_csv('popcorn_data.csv')
df
# Out:
#      Kernal id   popped   long length   short length  branch
# 0             1     True            30            25        2
# 1             2     True            35            10        3
# 2             3     True            37            20        2
# 3             4     True            21            18        2
# 4             5     True            18            14        1
# ..          ...      ...           ...           ...      ...
# 132         133    False             7             4        0
# 133         134    False             7             7        0
# 134         135    False             6             6        0
# 135         136     True            11            10        1
# 136         137    False             6             4        0
#
# [137 rows x 5 columns]

# %%
df['popped '].value_counts()
# Out:
# popped
# True     108
# False     29
# Name: count, dtype: int64

# %%
s = df['popped '].value_counts().plot.bar()

# %%
df['long length '].plot.hist(bins=5)
# Out:
# <Axes: ylabel='Frequency'>
